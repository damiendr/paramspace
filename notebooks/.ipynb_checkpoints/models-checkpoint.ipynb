# %%
import paramspace
from paramspace.traits_model import ModelTraits, load

# %%
from traits.api import Float, Range, Any

# %%
from paramspace.expressions import choice, uniform, normal, loguniform, quniform, PyllMapper

# %%
class TestModel(ModelTraits):
    x = Float(dist=uniform(0,1) + normal(0, 1.0))
    y = Any()
    z = Range(low=0.0, high=10.0, dist=quniform(0, 20, 0.5))

# %%
space = TestModel.space(
    y = choice(
            TestModel.space(x = 1 + uniform(0, 1)),
            3 * uniform(-1, -2),
    )
)

# %%
print space
# Out:
# __main__.TestModel(y=choice((__main__.TestModel(x=1 + uniform(0, 1), z=min(10.0, max(0.0, quniform(0, 20, 0.5)))), 3*uniform(-1, -2))), x=uniform(0, 1) + normal(0, 1.0), z=min(10.0, max(0.0, quniform(0, 20, 0.5))))

# %%
lspace = space.label_vars("space")

# %%
print lspace
# Out:
# __main__.TestModel(y=choice(space.y, (__main__.TestModel(x=1 + uniform(space.y.x, 0, 1), z=min(10.0, max(0.0, quniform(space.y.z, 0, 20, 0.5)))), 3*uniform(space.y_1, -1, -2))), x=uniform(space.x, 0, 1) + normal(space.x_1, 0, 1.0), z=min(10.0, max(0.0, quniform(space.z, 0, 20, 0.5))))

# %%
hpspace = PyllMapper()(lspace)
hpspace
# Out:
# {'__class__': '__main__.TestModel',
#  'x': <hyperopt.pyll.base.Apply at 0x107d56a50>,
#  'y': <hyperopt.pyll.base.Apply at 0x107d4b990>,
#  'z': <hyperopt.pyll.base.Apply at 0x107d4bc50>}

# %%
from hyperopt.pyll.stochastic import sample

# %%
sample(hpspace)
# Out:
# {'__class__': '__main__.TestModel',
#  'x': 1.1251225021388542,
#  'y': -4.787803798201757,
#  'z': 10.0}

# %%
load(sample(hpspace))
