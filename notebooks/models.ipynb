# %%
import paramspace
from paramspace.traits_model import ModelTraits, load

# %%
from traits.api import Float, Range, Any

# %%
from paramspace.expressions import choice, pchoice, uniform, normal, loguniform, quniform, PyllMapper

# %%
class TestModel(ModelTraits):
    x = Float(dist=uniform(0,1) + normal(0, 1.0))
    y = Any()
    z = Range(low=0.0, high=10.0, dist=quniform(0, 20, 0.5))

# %%
space = TestModel.space(
    y = pchoice(
            (0.1, TestModel.space(x = 1 + uniform(0, 1))),
            (0.9, 3 * uniform(-1, -2)),
    )
)

# %%
print space
# Out:
# __main__.TestModel(y=pchoice(((0.1, __main__.TestModel(x=1 + uniform(0, 1), z=min(10.0, max(0.0, quniform(0, 20, 0.5))))), (0.9, 3*uniform(-1, -2)))), x=uniform(0, 1) + normal(0, 1.0), z=min(10.0, max(0.0, quniform(0, 20, 0.5))))

# %%
lspace = space.label_vars("space")

# %%
print lspace
# Out:
# __main__.TestModel(y=pchoice(space.y, ((0.1, __main__.TestModel(x=1 + uniform(space.y.x, 0, 1), z=min(10.0, max(0.0, quniform(space.y.z, 0, 20, 0.5))))), (0.9, 3*uniform(space.y_1, -1, -2)))), x=uniform(space.x, 0, 1) + normal(space.x_1, 0, 1.0), z=min(10.0, max(0.0, quniform(space.z, 0, 20, 0.5))))

# %%
hpspace = PyllMapper()(lspace)
hpspace
# Out:
# {'__class__': '__main__.TestModel',
#  'x': <hyperopt.pyll.base.Apply at 0x109ebdcd0>,
#  'y': <hyperopt.pyll.base.Apply at 0x109ebd850>,
#  'z': <hyperopt.pyll.base.Apply at 0x109ebd910>}

# %%
print hpspace["y"]
# Out:
# 0 switch
# 1   hyperopt_param
# 2     Literal{space.y}
# 3     categorical
# 4       pos_args
# 5         Literal{0.1}
# 6         Literal{0.9}
# 7      upper =
# 8       Literal{2}
# 9   dict
# 10    __class__ =
# 11     Literal{__main__.TestModel}
# 12    x =
# 13     add
# 14       Literal{1}
# 15       float
# 16         hyperopt_param
# 17           Literal{space.y.x}
# 18           uniform
# 19             Literal{0}
# 20             Literal{1}
# 21    z =
# 22     min
# 23       Literal{10.0}
# 24       max
# 25         Literal{0.0}
# 26         float
# 27           hyperopt_param
# 28             Literal{space.y.z}
# 29             quniform
# 30               Literal{0}
# 31               Literal{20}
# 32               Literal{0.5}
# 33   mul
# 34     Literal{3}
# 35     float
# 36       hyperopt_param
# 37         Literal{space.y_1}
# 38         uniform
# 39           Literal{-1}
# 40           Literal{-2}

# %%
from hyperopt.pyll.stochastic import sample

# %%
for _ in range(10): print sample(hpspace)
# Out:
# {'y': -3.3939037625353237, 'x': 1.4279263654837964, 'z': 10.0, '__class__': '__main__.TestModel'}
# {'y': -3.0688173284368805, 'x': 0.48182480829322055, 'z': 10.0, '__class__': '__main__.TestModel'}
# {'y': -4.045872313336487, 'x': -0.24410349299860934, 'z': 4.0, '__class__': '__main__.TestModel'}
# {'y': -4.9602787408015185, 'x': 0.11766283660139928, 'z': 10.0, '__class__': '__main__.TestModel'}
# {'y': -3.2519528444541588, 'x': -0.631105133567799, 'z': 10.0, '__class__': '__main__.TestModel'}
# {'y': -3.8937620784312537, 'x': 0.2521387564179733, 'z': 1.0, '__class__': '__main__.TestModel'}
# {'y': -3.4600499399885285, 'x': 0.7950632413273127, 'z': 10.0, '__class__': '__main__.TestModel'}
# {'y': -4.54158826729009, 'x': -1.0615022610723486, 'z': 10.0, '__class__': '__main__.TestModel'}
# {'y': -4.2589830487063765, 'x': 1.301964029772594, 'z': 10.0, '__class__': '__main__.TestModel'}
# {'y': -3.497897455655843, 'x': -1.5944297690679674, 'z': 10.0, '__class__': '__main__.TestModel'}

# %%
load(sample(hpspace))
