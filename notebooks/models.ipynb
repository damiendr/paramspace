# %%
import paramspace
from paramspace.traits_model import ModelTraits

# %%
from traits.api import Float, Range, Any

# %%
from scipy.stats import uniform

# %%
from hyperopt import hp

# %%
class TestModel(ModelTraits):
    x = Float(dist=uniform(0,1))
    y = Any()

# %%
space = TestModel.space(
    y = TestModel.space()
)

# %%
space
# Out:
# {'__module__': '__main__',
#  '__name__': 'TestModel',
#  'x': <hyperopt.pyll.base.Apply at 0x10c61b8d0>,
#  'y': {'__module__': '__main__',
#   '__name__': 'TestModel',
#   'x': <hyperopt.pyll.base.Apply at 0x10c61ba90>}}

# %%
from hyperopt.pyll.stochastic import Apply, sample
sample(space)
# Out:
# {'__module__': '__main__',
#  '__name__': 'TestModel',
#  'x': 0.5772552158799423,
#  'y': {'__module__': '__main__',
#   '__name__': 'TestModel',
#   'x': 0.48949493629800933}}

# %%
print space["x"]
print space["y"]["x"]
# Out:
# 0 float
# 1   hyperopt_param
# 2     Literal{.x}
# 3     uniform
# 4       Literal{0}
# 5       Literal{1}
# 0 float
# 1   hyperopt_param
# 2     Literal{.x}
# 3     uniform
# 4       Literal{0}
# 5       Literal{1}
